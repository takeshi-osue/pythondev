# %%
price_without_tax = int(input("税抜価格を入力してください："))
price_with_tax_raw = price_without_tax * 1.1
price_with_tax = int(price_with_tax_raw)
shipping_fee = 0
final_price = price_with_tax

if price_with_tax >= 2000: print("送料は無料です")
else: shipping_fee = 350
final_price = price_with_tax + shipping_fee
print(f"送料込みの価格は{final_price}円です。")
# Out:
# 送料込みの価格は2330円です。

# %%
price_without_tax = int(input("税抜価格を入力してください："))
price_with_tax_raw = price_without_tax * 1.1
price_with_tax = int(price_with_tax_raw)
shipping_fee = 0
final_price = price_with_tax

if price_with_tax >= 2000: print("送料は無料です")
else: shipping_fee = 350
final_price = price_with_tax + shipping_fee
print(f"送料込みの価格は{final_price}円です。")
# Out:
# 送料は無料です
# 送料込みの価格は2200円です。
